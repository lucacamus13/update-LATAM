# %% [markdown]
# <a href="https://colab.research.google.com/github/lucacamus13/update-LATAM/blob/main/update_LATAM%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance investpy pandas matplotlib seaborn plotly pytz
# !pip install investpy
# !pip install fredapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 33.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 11.3 MB/s eta 0:00:00
# ...
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481565 sha256=f63111410460868cf8d07d2597e290cdbf4a15dd8968dbe82de2bb8320d86b37
#   Stored in directory: /root/.cache/pip/wheels/df/e8/50/8d6a7119bc8829b70c66573d84e09873d611f9244cf5a1d1b2
# Successfully built investpy
# ...

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime
import time
import pytz
import investpy

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Rectangle
import pandas as pd
import numpy as np
from datetime import datetime
import os

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import requests
import re
from bs4 import BeautifulSoup
import warnings

# %% [markdown]
# # Comparativo bolsas LATAM

# %% [markdown]
# ## Defino la tabla
# Esta función descarga y calcula el nivel actual y la variación diaria de los principales índices bursátiles de 6 países LATAM: Brasil, Chile, México, Colombia, Perú y Argentina.
#
# El primero suele ser el índice real del país (^IPSA), el segundo un ETF como respaldo (ECH).

# %%
def obtener_bolsas_latam_ipsa():
    """Versión que prioriza el IPSA real para Chile"""

    # Configuración con símbolos mejorados
    indices = {
        'BRASIL': {
            'simbolos': ['^BVSP', 'EWZ'],
            'nombre': 'Bovespa'
        },
        'CHILE': {
            'simbolos': ['^IPSA', 'ECH'],  # IPSA primero, ETF como respaldo
            'nombre': 'IPSA'
        },
        'MÉXICO': {
            'simbolos': ['^MXX', 'EWW'],
            'nombre': 'IPC'
        },
        'COLOMBIA': {
            'simbolos': ['^SPCOSLCP', '^COLCAP', 'ICOL','GXG'],  # S&P Colombia Select funciona mejor
            'nombre': 'COLCAP'
        },
        'PERÚ': {
            'simbolos': ['^SPBLPGPT', 'EPU'],
            'nombre': 'BVL'
        },
        'ARGENTINA': {
            'simbolos': ['^MERV', 'IAR.BA', 'ARGT'],  # MERVAL oficial
            'nombre': 'MERVAL'
        }
    }

    datos = []


    for pais, info in indices.items():
        print(f"\n📊 Obteniendo datos para {pais} ({info['nombre']})...")
        datos_obtenidos = False

        for i, simbolo in enumerate(info['simbolos']):
            try:
                print(f"   {'🎯' if i == 0 else '🔄'} Probando: {simbolo}")

                ticker = yf.Ticker(simbolo)

                # Obtener historial con suficientes días para 5d and 30d lookback
                hist = ticker.history(period="60d")

                if len(hist) >= 2:
                    precio_actual = hist['Close'].iloc[-1]
                    precio_anterior = hist['Close'].iloc[-2]
                    cambio_pct = ((precio_actual - precio_anterior) / precio_anterior) * 100

                    # Calcular variación 5 días hábiles (aproximadamente)
                    precio_5d_ago = None
                    cambio_5d_pct_str = 'N/D'
                    if len(hist) >= 5:
                        precio_5d_ago = hist['Close'].iloc[-5]
                        cambio_5d_pct = ((precio_actual - precio_5d_ago) / precio_5d_ago) * 100
                        cambio_5d_pct_str = f"{cambio_5d_pct:+.2f}%"


                    # Calcular variación 30 días hábiles (aproximadamente)
                    precio_30d_ago = None
                    cambio_30d_pct_str = 'N/D'
                    if len(hist) >= 30:
                        precio_30d_ago = hist['Close'].iloc[-30]
                        cambio_30d_pct = ((precio_actual - precio_30d_ago) / precio_30d_ago) * 100
                        cambio_30d_pct_str = f"{cambio_30d_pct:+.2f}%"


                    # Verificar que los datos son válidos
                    if precio_actual > 0 and not pd.isna(precio_actual):

                        # Obtener información adicional del ticker
                        try:
                            info_ticker = ticker.info
                            nombre_completo = info_ticker.get('longName', info['nombre'])
                        except:
                            nombre_completo = info['nombre']

                        # Determinar estado del mercado
                        now = datetime.now()
                        # Check if it's a weekend (Saturday = 5, Sunday = 6)
                        if now.weekday() >= 5:
                            estado = "CERRADO"
                        else:
                           # Horario aproximado de mercados latinoamericanos (GMT-3 a GMT-5)
                           estado = "ABIERTO" if 9 <= now.hour <= 17 else "CERRADO"


                        # Formatear precio según el índice
                        if pais == 'CHILE' and simbolo == '^IPSA':
                            # El IPSA suele estar en miles
                            nivel_str = f"{precio_actual:,.0f}"
                        elif pais == 'ARGENTINA' and simbolo == '^MERV':
                            # El MERVAL está en millones
                            nivel_str = f"{precio_actual:,.0f}"
                        elif precio_actual >= 1000:
                            nivel_str = f"{precio_actual:,.0f}"
                        else:
                            nivel_str = f"{precio_actual:,.2f}"


                        datos.append({
                            'Índices': pais,
                            'Estado': estado,
                            'Nivel': nivel_str,
                            'Var%': f"{cambio_pct:+.2f}%",
                            'Var 5d%': cambio_5d_pct_str,
                            'Var 30d%': cambio_30d_pct_str,
                            'Símbolo_Usado': simbolo,
                            'Tipo': 'Índice' if i == 0 else 'ETF'
                        })

                        tipo_msg = "✅ ÍNDICE OFICIAL" if i == 0 else "✅ ETF (respaldo)"
                        print(f"   {tipo_msg}: {nivel_str} ({cambio_pct:+.2f}%) | 5d: {datos[-1]['Var 5d%']} | 30d: {datos[-1]['Var 30d%']}")
                        datos_obtenidos = True
                        break
                    else:
                        print(f"   ⚠️  Datos inválidos para {simbolo}")

                else:
                    print(f"   ⚠️  Insuficientes datos históricos para {simbolo}")

            except Exception as e:
                print(f"   ❌ Error con {simbolo}: {str(e)[:50]}...")
                continue

        # Si no se obtuvieron datos con ningún símbolo
        if not datos_obtenidos:
            print(f"   ⚠️  No se pudieron obtener datos para {pais}")
            datos.append({
                'Índices': pais,
                'Estado': 'N/D',
                'Nivel': 'N/D',
                'Var%': 'N/D',
                'Var 5d%': 'N/D',
                'Var 30d%': 'N/D',
                'Símbolo_Usado': 'N/D',
                'Tipo': 'N/D'
            })

    return datos

# %% [markdown]
# ## Crear tabla
# Crea un DataFrame legible con pandas para mostrarlo tipo tabla.
#
# También muestra qué símbolo se usó (índice real o ETF).

# %%
def mostrar_tabla_con_ipsa():
    """Mostrar la tabla con todos los países incluido Argentina"""
    print("🔄 Obteniendo datos de Bolsas Latam (6 países)...")
    print("=" * 70)

    datos = obtener_bolsas_latam_ipsa()

    # Crear DataFrame para mostrar (sin columnas técnicas)
    df_mostrar = pd.DataFrame([{
        'Índices': d['Índices'],
        'Estado': d['Estado'],
        'Nivel': d['Nivel'],
        'Var%': d['Var%'],
        'Var 5d%': d['Var 5d%'], # Include the new 5d variation column
        'Var 30d%': d['Var 30d%'] # Include the 30d variation column
    } for d in datos])

    # Filter out rows where 'Nivel' is 'N/D'
    df_mostrar = df_mostrar[df_mostrar['Nivel'] != 'N/D'].reset_index(drop=True)


    print("\n" + "="*70)
    print("                        BOLSAS LATAM")
    print("="*70)
    print(df_mostrar.to_string(index=False))
    print("="*70)

    # Obtener la hora actual en UTC y convertirla a la zona horaria de Santiago
    utc_now = datetime.now(pytz.utc)
    santiago_timezone = pytz.timezone('America/Santiago')
    santiago_time = utc_now.astimezone(santiago_timezone)

    print(f"🕐 Actualizado: {santiago_time.strftime('%Y-%m-%d %H:%M:%S')}")


    # Mostrar detalles técnicos
    print("\n📋 Detalles técnicos:")
    for dato in datos:
        if dato['Símbolo_Usado'] != 'N/D':
            tipo_emoji = "🎯" if dato['Tipo'] == 'Índice' else "📈"
            print(f"   {tipo_emoji} {dato['Índices']}: {dato['Símbolo_Usado']} ({dato['Tipo']})")

    return df_mostrar

# %% [markdown]
# ## Debug
#
# Se usa para hacer debug manual de Colombia y Argentina.
#
# Prueba los símbolos uno por uno.
#
# Imprime si devuelve datos válidos (✅) o no (❌).
#
# Útil para identificar si Yahoo Finance está fallando con algún ticker puntual.

# %%
# Función específica para verificar índices problemáticos
def verificar_indices_especificos():
    """Verificar específicamente Colombia y Argentina"""
    print("🔍 Verificando índices específicos...")

    # Verificar Colombia
    print("\n📊 COLOMBIA (COLCAP):")
    simbolos_colombia = ['^SPCOSLCP', '^COLCAP', 'ICOL','GXG']

    for simbolo in simbolos_colombia:
        try:
            ticker = yf.Ticker(simbolo)
            hist = ticker.history(period="2d")

            if len(hist) > 0:
                precio = hist['Close'].iloc[-1]
                print(f"   ✅ {simbolo}: {precio:.2f}")
            else:
                print(f"   ❌ {simbolo}: Sin datos")
        except Exception as e:
            print(f"   ❌ {simbolo}: Error - {str(e)[:30]}...")

    # Verificar Argentina
    print("\n📊 ARGENTINA (MERVAL):")
    simbolos_argentina = ['^MERV', 'IAR.BA', 'ARGT']

    for simbolo in simbolos_argentina:
        try:
            ticker = yf.Ticker(simbolo)
            hist = ticker.history(period="2d")

            if len(hist) > 0:
                precio = hist['Close'].iloc[-1]
                print(f"   ✅ {simbolo}: {precio:,.0f}")
            else:
                print(f"   ❌ {simbolo}: Sin datos")
        except Exception as e:
            print(f"   ❌ {simbolo}: Error - {str(e)[:30]}...")

# %% [markdown]
# Sirve para corroborar que estás bajando el índice correcto desde Yahoo.

# %%
# Función específica para verificar el IPSA
def verificar_ipsa():
    """Función específica para verificar el estado del IPSA"""
    print("🔍 Verificando específicamente el IPSA de Chile...")

    try:
        ipsa = yf.Ticker('^IPSA')

        # Obtener información básica
        info = ipsa.info
        print(f"📊 Información del IPSA:")
        print(f"   Nombre: {info.get('longName', 'S&P IPSA')}")
        print(f"   Moneda: {info.get('currency', 'CLP')}")
        print(f"   Mercado: {info.get('market', 'Santiago')}")

        # Obtener datos históricos
        hist = ipsa.history(period="5d")

        if len(hist) > 0:
            print(f"\n📈 Datos recientes del IPSA:")
            print(f"   Último precio: {hist['Close'].iloc[-1]:.2f}")
            print(f"   Fecha: {hist.index[-1].strftime('%Y-%m-%d')}")

            if len(hist) >= 2:
                cambio = ((hist['Close'].iloc[-1] - hist['Close'].iloc[-2]) / hist['Close'].iloc[-2]) * 100
                print(f"   Cambio diario: {cambio:+.2f}%")

            return True
        else:
            print("❌ No se encontraron datos históricos")
            return False

    except Exception as e:
        print(f"❌ Error al verificar IPSA: {e}")
        return False

# %% [markdown]
# ## Convertimos el df a png

# %%
def mostrar_dataframe_como_imagen(df, title="Análisis Bolsas Latam"):
    """
    Muestra un DataFrame como imagen en el output sin guardar archivo
    """
    # Configurar el tamaño de la figura (ajustado para ser más pequeño)
    fig, ax = plt.subplots(figsize=(12, 2.5)) # Reduced figure size
    ax.axis('tight')
    ax.axis('off')
    ax.grid(False) # Remove grid

    # Crear la tabla
    table = ax.table(cellText=df.values,
                    colLabels=df.columns,
                    cellLoc='center',
                    loc='center',
                    bbox=[0, 0, 1, 1])

    # Personalizar el estilo de la tabla (ajustado para fuente más grande)
    table.auto_set_font_size(False)
    table.set_fontsize(12) # Increased font size
    table.scale(1.2, 2)

    # Colorear el encabezado
    for i in range(len(df.columns)):
        table[(0, i)].set_facecolor('#000080') # Navy blue color
        table[(0, i)].set_text_props(weight='bold', color='white')

    # Colorear las filas alternadas y las variaciones
    for i in range(1, len(df) + 1):
        for j in range(len(df.columns)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#f0f0f0')
            else:
                table[(i, j)].set_facecolor('white')

            # Colorear las columnas de variación
            if df.columns[j] in ['Var%', 'Var 5d%', 'Var 30d%']:
                cell_text = table[(i, j)].get_text().get_text()
                if cell_text.startswith('+'):
                    table[(i, j)].set_text_props(color='green')
                elif cell_text.startswith('-'):
                    table[(i, j)].set_text_props(color='red')


    # Agregar título con fecha y hora local
    # Obtener la hora actual en UTC y convertirla a la zona horaria de Santiago
    utc_now = datetime.now(pytz.utc)
    santiago_timezone = pytz.timezone('America/Santiago')
    santiago_time = utc_now.astimezone(santiago_timezone)
    current_time_str = santiago_time.strftime("%Y-%m-%d %H:%M:%S")

    plt.title(f'{title}\n(Actualizado: {current_time_str})', fontsize=14, fontweight='bold', pad=20)

    # Agregar marca de agua
    plt.figtext(0.95, 0.05, '@camusluca',
                fontsize=10, color='gray', ha='center', va='bottom', alpha=0.5)

    # Agregar timestamp (redundante con el título, pero se mantiene por si acaso)
    # plt.figtext(0.02, 0.02, f'Generado: {timestamp}', fontsize=8, alpha=0.7)

    # Mostrar la imagen en el output
    plt.tight_layout()
    plt.show()

    print(f"✅ DataFrame mostrado como imagen en el output")
    return fig

def mostrar_multiples_vistas(df):
    """
    Muestra múltiples vistas del DataFrame en el output
    """
    # Vista completa
    mostrar_dataframe_como_imagen(df, "Análisis Completo - Bolsas Latam (6 países)")

    # # Vista resumida (if needed - currently commented out)
    # if len(df.columns) > 6:
    #     # Select the first 6 most relevant columns
    #     df_resumido = df.iloc[:, :6]
    #     mostrar_dataframe_como_imagen(df_resumido, "Vista Resumida - Bolsas Latam")

    # # Vista con estadísticas básicas (if needed - currently commented out)
    # if df.select_dtypes(include=[np.number]).shape[1] > 0:
    #     df_stats = df.describe()
    #     mostrar_dataframe_como_imagen(df_stats, "Estadísticas Descriptivas - Bolsas Latam")

# %% [markdown]
# ## Ejecutamos

# %%
# Ejecutar
if __name__ == "__main__":
    print("🚀 Iniciando análisis de Bolsas Latam (6 países)")
    print("=" * 70)

    # Verificar índices específicos
    verificar_indices_especificos()

    print("\n" + "=" * 70)

    # Ejecutar función principal y capturar el DataFrame
    df_resultado = mostrar_tabla_con_ipsa()

    print("\n" + "=" * 70)
    print("📊 Mostrando DataFrame como imagen en el output...")

    # Verificar si se obtuvo un DataFrame
    if df_resultado is not None and isinstance(df_resultado, pd.DataFrame):
        # Mostrar imagen principal
        mostrar_dataframe_como_imagen(df_resultado, "Análisis Bolsas Latam - 6 Países")

        # Mostrar múltiples vistas (if needed - currently commented out)
        # mostrar_multiples_vistas(df_resultado)

        print("✅ Todas las imágenes han sido mostradas en el output")
    else:
        print("❌ No se pudo obtener el DataFrame para mostrar las imágenes")
        print("   Verifica que la función mostrar_tabla_con_ipsa() retorne un DataFrame")

    print("\n" + "=" * 70)
    print("🎯 Análisis completado exitosamente!")
# Out:
# 🚀 Iniciando análisis de Bolsas Latam (6 países)
# ...
# 🔍 Verificando índices específicos...
#
# 📊 COLOMBIA (COLCAP):
#    ✅ ^SPCOSLCP: 1229.42
# ERROR:yfinance:HTTP Error 404:
# ERROR:yfinance:$^COLCAP: possibly delisted; no price data found  (period=2d) (Yahoo error = "No data found, symbol may be delisted")
# ERROR:yfinance:$ICOL: possibly delisted; no price data found  (period=2d)
#    ❌ ^COLCAP: Sin datos
#    ❌ ICOL: Sin datos
#    ✅ GXG: 29.05
#
# 📊 ARGENTINA (MERVAL):
#    ✅ ^MERV: 2,304,342
# ERROR:yfinance:$IAR.BA: possibly delisted; no price data found  (period=2d)
#    ❌ IAR.BA: Sin datos
#    ✅ ARGT: 85
#
# ...
# 🔄 Obteniendo datos de Bolsas Latam (6 países)...
# ...
#
# 📊 Obteniendo datos para BRASIL (Bovespa)...
#    🎯 Probando: ^BVSP
#    ✅ ÍNDICE OFICIAL: 132,726 (+0.45%) | 5d: -1.95% | 30d: -4.40%
#
# 📊 Obteniendo datos para CHILE (IPSA)...
#    🎯 Probando: ^IPSA
#    ⚠️  Insuficientes datos históricos para ^IPSA
#    🔄 Probando: ECH
# ...

# %% [markdown]
# # ETF's

# %%
# Definimos tickers y nombres correctos
ticker_dict = {
    "EWZ": "ETF Brasil",
    "EWW": "ETF México",
    "ECH": "ETF Chile",
    "GXG": "ETF Colombia",
    #"ARGT": "ETF Argentina",
    "SPY": "S&P 500"
}

# Descargar precios ajustados
data = yf.download(list(ticker_dict.keys()), start="2024-07-01", end="2025-07-18")['Close']

# Renombrar columnas usando el diccionario
data = data.rename(columns=ticker_dict)

# Asegurar datos limpios
data = data.dropna()
data_norm = data / data.iloc[0] * 100
# Out:
# /tmp/ipython-input-9-2646050697.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list(ticker_dict.keys()), start="2024-07-01", end="2025-07-18")['Close']
# [*********************100%***********************]  5 of 5 completed

# %%
# Diccionario de tickers con nombres correctos
ticker_dict = {
    "EWZ": "ETF Brasil",
    #"ARGT": "ETF Argentina",
    "EWW": "ETF México",
    "ECH": "ETF Chile",
    "GXG": "ETF Colombia",
    "SPY": "S&P 500"
}

# Descargar precios ajustados (último año)
from datetime import datetime, timedelta

# Get today's date
end_date = datetime.now()

# Calculate the start date (1 year ago)
start_date = end_date - timedelta(days=365)


data = yf.download(list(ticker_dict.keys()), start=start_date, end=end_date)['Close']

# Renombrar columnas para que coincidan con países
data = data.rename(columns=ticker_dict)

# Eliminar fechas sin datos en todos los ETFs
data = data.dropna()

# Normalizar precios base 100 (rendimiento acumulado)
data_norm = data / data.iloc[0] * 100

# Graficar
plt.style.use("seaborn-v0_8-colorblind")
plt.figure(figsize=(12,6))
for col in data_norm.columns:
    plt.plot(data_norm.index, data_norm[col], label=col)

plt.title('📈 Rendimiento Acumulado: ETFs LATAM vs. S&P 500 (Base 100)', fontsize=14)
plt.ylabel('Índice Normalizado (Base 100)')
plt.xlabel('Fecha')
plt.legend()
# plt.grid(True) # Remove this line or comment it out
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-10-2171836272.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list(ticker_dict.keys()), start=start_date, end=end_date)['Close']
# [*********************100%***********************]  5 of 5 completed
# /tmp/ipython-input-10-2171836272.py:43: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Monedas

# %% [markdown]
# ## Datos
# Obtiene datos de monedas latinoamericanas respecto al dólar (USD) desde Yahoo Finance.

# %%
def get_currency_data():
    """Obtiene datos de monedas latinoamericanas vs USD"""

    # Símbolos de las monedas en Yahoo Finance
    currencies = {
        'USD/REAL': 'BRL=X',
        'USD/CLP': 'CLP=X',
        'USD/MEX': 'MXN=X',
        'USD/COP': 'COP=X',
        'USD/PEN': 'PEN=X',
         'USD/ARS': 'ARS=X'
    }

    results = []

    # Obtener datos para cada moneda
    for name, symbol in currencies.items():
        try:
            # Obtener datos de los últimos 15 días para asegurar 7 días para variación semanal
            ticker = yf.Ticker(symbol)
            hist = ticker.history(period='15d')

            if len(hist) >= 2:
                # Precio actual (último precio disponible)
                current_price = hist['Close'].iloc[-1]

                # Precio anterior (día anterior)
                prev_price = hist['Close'].iloc[-2]

                # Precio hace 7 días (aproximadamente)
                price_7d_ago = None
                if len(hist) >= 7:
                    price_7d_ago = hist['Close'].iloc[-7] # Tomar el precio de hace 7 días calendario
                    var_7d_pct = ((current_price - price_7d_ago) / price_7d_ago) * 100
                else:
                    var_7d_pct = float('nan') # No hay suficientes datos


                # Calcular variación absoluta y porcentual diaria
                var_1d = current_price - prev_price
                var_1d_pct = (var_1d / prev_price) * 100

                results.append({
                    'Monedas': name,
                    'Precio': current_price,
                    'Var 1d': var_1d,
                    '1d%': var_1d_pct,
                    '7d%': var_7d_pct if not pd.isna(var_7d_pct) else 'N/D'
                })
            else:
                print(f"No hay suficientes datos para {name}")

        except Exception as e:
            print(f"Error obteniendo datos para {name}: {e}")

    return pd.DataFrame(results)

# %% [markdown]
# ##Crear tabla
#
# Genera una imagen PNG de la tabla con los datos de monedas.

# %%
def create_currency_image(df, filename='monedas_latam.png'):
    """Crea una imagen PNG de la tabla de monedas"""

    if df.empty:
        print("No se puede crear imagen sin datos")
        return

    # Configurar la figura
    fig, ax = plt.subplots(figsize=(8, 2.5))
    ax.axis('tight')
    ax.axis('off')

    # Preparar datos para la tabla
    table_data = []
    headers = ['Monedas', 'Precio', 'Var 1d', '1d%', '7d%']

    # Formatear los datos
    for _, row in df.iterrows():
        precio = f"{row['Precio']:,.3f}"
        var_1d = f"{row['Var 1d']:+.3f}" if abs(row['Var 1d']) >= 0.001 else f"{row['Var 1d']:+.4f}"
        var_pct_1d = f"{row['1d%']:+.2f}%"
        var_pct_7d = f"{row['7d%']:+.2f}%" if not pd.isna(row['7d%']) else 'N/D'


        table_data.append([
            row['Monedas'],
            precio,
            var_1d,
            var_pct_1d,
            var_pct_7d
        ])

    # Crear la tabla
    table = ax.table(cellText=table_data,
                    colLabels=headers,
                    cellLoc='center',
                    loc='center',
                    colWidths=[0.2, 0.2, 0.2, 0.15, 0.15])

    # Estilo de la tabla
    table.auto_set_font_size(False)
    table.set_fontsize(11)
    table.scale(1.2, 2)

    # Estilo del encabezado
    for i in range(len(headers)):
        table[(0, i)].set_facecolor('#000080')
        table[(0, i)].set_text_props(weight='bold', color='white')

    # Estilo de las filas
    for i in range(1, len(table_data) + 1):
        for j in range(len(headers)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#F2F2F2')
            else:
                table[(i, j)].set_facecolor('white')

            # Colorear las variaciones
            if headers[j] in ['1d%', '7d%']:  # Columnas de variación
                cell_text = table[(i, j)].get_text().get_text()
                if cell_text.startswith('+'):
                    table[(i, j)].set_text_props(color='green')
                elif cell_text.startswith('-'):
                    table[(i, j)].set_text_props(color='red')

    # Título
    plt.title('MONEDAS', fontsize=16, fontweight='bold', pad=20)

    # Guardar la imagen
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
    plt.show()

    print(f"Imagen guardada como: {filename}")

# %% [markdown]
# ## Imprimir tabla
# Imprime la tabla de monedas en consola con formato limpio.

# %%
def format_currency_table(df):
    """Formatea la tabla para mostrar como en la imagen"""

    if df.empty:
        print("No se pudieron obtener datos de monedas")
        return

    print("MONEDAS")
    print("=" * 60)
    print(f"{'Monedas':<12} {'Precio':<12} {'Var 1d':<10} {'1d%':<8} {'7d%':<8}")
    print("-" * 60)

    for _, row in df.iterrows():
        moneda = row['Monedas']
        precio = f"{row['Precio']:,.3f}"
        var_1d = f"{row['Var 1d']:+.3f}" if abs(row['Var 1d']) >= 0.001 else f"{row['Var 1d']:+.4f}"
        var_pct_1d = f"{row['1d%']:+.2f}%"
        var_pct_7d = f"{row['7d%']:+.2f}%" if not pd.isna(row['7d%']) else 'N/D'


        print(f"{moneda:<12} {precio:<12} {var_1d:<10} {var_pct_1d:<8} {var_pct_7d:<8}")

# %% [markdown]
# Devuelve un DataFrame con valores formateados como texto:
#
# Precio: con 3 decimales y comas.
#
# Variaciones: con signo y 2 decimales.

# %%
def create_formatted_dataframe(df):
    """Crea un DataFrame formateado para mejor visualización"""

    if df.empty:
        return pd.DataFrame()

    # Crear copia del DataFrame
    formatted_df = df.copy()

    # Formatear columnas
    formatted_df['Precio'] = formatted_df['Precio'].apply(lambda x: f"{x:,.3f}")
    formatted_df['Var 1d'] = formatted_df['Var 1d'].apply(lambda x: f"{x:+.3f}" if abs(x) >= 0.001 else f"{x:+.4f}")
    formatted_df['1d%'] = formatted_df['1d%'].apply(lambda x: f"{x:+.2f}%")

    return formatted_df

# %% [markdown]
# ## Ejecutar
# Corre todo el proceso:
#
# Obtiene datos.
#
# Muestra tabla en consola.
#
# Crea la imagen.
#
# Retorna el DataFrame.

# %%
# Función principal
def main():
    print("Obteniendo datos de monedas latinoamericanas...")

    # Obtener datos
    df = get_currency_data()

    if not df.empty:
        # Filter out rows where 'Precio' is missing or invalid
        df = df.dropna(subset=['Precio']).reset_index(drop=True)
        # Also filter out rows where 'Precio' is 0 or less (invalid price)
        df = df[df['Precio'] > 0].reset_index(drop=True)


        # Mostrar tabla formateada en consola
        format_currency_table(df)

        # Crear imagen PNG
        create_currency_image(df)

        return df
    else:
        print("No se pudieron obtener datos de ninguna moneda")
        return None

# Ejecutar el código
if __name__ == "__main__":
    currency_data = main()
# Out:
# Obteniendo datos de monedas latinoamericanas...
# MONEDAS
# ...
# Monedas      Precio       Var 1d     1d%      7d%
# ------------------------------------------------------------
# USD/REAL     5.574        -0.013     -0.23%   +0.15%
# USD/CLP      970.460      +33.557    +3.58%   +0.73%
# USD/MEX      18.747       +0.0000    +0.00%   +0.49%
# USD/COP      4,140.820    -32.770    -0.79%   +2.66%
# USD/PEN      3.552        -0.091     -2.50%   -0.20%
# USD/ARS      1,291.000    -2.846     -0.22%   +1.34%
# Imagen guardada como: monedas_latam.png

# %% [markdown]
# # Comoditties

# %% [markdown]
# ## Datos
# Obtiene los datos de los commodities y calcula sus variaciones.

# %%
def get_commodities_data(fecha_especifica=None):
    """Obtiene datos de commodities/futuros"""

    # Símbolos de commodities en Yahoo Finance
    commodities = {
        'Brent': 'BZ=F',        # Petróleo Brent
        'M. de hierro': 'IRON',  # Mineral de hierro (puede no estar disponible)
        'Cobre': 'HG=F',        # Cobre futuros
        'Gas Natural':'NG=F',    # Gas Futuros Aug25
        'Litio': 'LIT',         # ETF de Litio (alternativa)
        'Oro': 'GC=F',          # Oro futuros
        'Café': 'KC=F',         # Café futuros
        'Soja': 'ZS=F'          # Soja futuros
    }

    results = []

    # Obtener datos para cada commodity
    for name, symbol in commodities.items():
        try:
            ticker = yf.Ticker(symbol)

            if fecha_especifica:
                # Obtener datos desde una fecha específica
                fecha_inicio = datetime.strptime(fecha_especifica, '%Y-%m-%d') - timedelta(days=15) # Get more data for weekly calc
                fecha_fin = datetime.strptime(fecha_especifica, '%Y-%m-%d') + timedelta(days=1)
                hist = ticker.history(start=fecha_inicio, end=fecha_fin)
            else:
                # Obtener datos de los últimos 15 días para calcular variación semanal
                hist = ticker.history(period='15d')


            if len(hist) >= 2:
                # Precio actual (último precio disponible)
                current_price = hist['Close'].iloc[-1]

                # Precio anterior (día anterior)
                prev_price = hist['Close'].iloc[-2]

                # Precio hace 5 días hábiles (aproximadamente)
                price_5d_ago = None
                if len(hist) >= 5:
                    price_5d_ago = hist['Close'].iloc[-5]
                    var_5d_pct = ((current_price - price_5d_ago) / price_5d_ago) * 100
                else:
                    var_5d_pct = float('nan')


                # Precio hace 1 mes aproximadamente (22 días hábiles)
                hist_1m = ticker.history(period='1mo')
                if len(hist_1m) >= 22:
                    price_1m = hist_1m['Close'].iloc[-22]
                else:
                    price_1m = hist_1m['Close'].iloc[0]


                # Calcular variaciones
                var_1d = current_price - prev_price
                var_1d_pct = (var_1d / prev_price) * 100

                var_1m_pct = ((current_price - price_1m) / price_1m) * 100

                results.append({
                    'Futuros': name,
                    'Precio': current_price,
                    '1d%': var_1d_pct,
                    '5d%': var_5d_pct, # Add 5d variation
                    '1m%': var_1m_pct
                })
            else:
                print(f"No hay suficientes datos para {name}")

        except Exception as e:
            print(f"Error obteniendo datos para {name}: {e}")

    return pd.DataFrame(results)

# %% [markdown]
# ## Crear tabla
# Crea una tabla con estilo: alterna colores de filas, cambia color del texto según signo de la variación, y usa encabezado azul.

# %%
def create_commodities_image(df, filename='commodities.png'):
    """Crea una imagen PNG de la tabla de commodities"""

    if df.empty:
        print("No se puede crear imagen sin datos")
        return

    # Configurar la figura
    fig, ax = plt.subplots(figsize=(10, 3.5))
    ax.axis('tight')
    ax.axis('off')

    # Preparar datos para la tabla
    table_data = []
    headers = ['Futuros', 'Precio', '1d%', '5d%', '1m%']

    # Formatear los datos
    for _, row in df.iterrows():
        # Formatear precio según el commodity
        if row['Futuros'] in ['Litio', 'Oro']:
            precio = f"{row['Precio']:.2f}"
        elif row['Futuros'] == 'M. de hierro':
            precio = f"{row['Precio']:.1f}"
        else:
            precio = f"{row['Precio']:.2f}"

        var_1d = f"{row['1d%']:+.2f}%"
        var_5d = f"{row['5d%']:+.2f}%" if not pd.isna(row['5d%']) else 'N/D' # Include 5d variation
        var_1m = f"{row['1m%']:+.1f}%"

        table_data.append([
            row['Futuros'],
            precio,
            var_1d,
            var_5d, # Add 5d variation
            var_1m
        ])

    # Crear la tabla
    table = ax.table(cellText=table_data,
                    colLabels=headers,
                    cellLoc='center',
                    loc='center',
                    colWidths=[0.3, 0.15, 0.15, 0.15, 0.15]) # Adjusted colWidths

    # Estilo de la tabla
    table.auto_set_font_size(False)
    table.set_fontsize(11)
    table.scale(1.2, 2)

    # Estilo del encabezado
    for i in range(len(headers)):
        table[(0, i)].set_facecolor('#000080')
        table[(0, i)].set_text_props(weight='bold', color='white')

    # Estilo de las filas
    for i in range(1, len(table_data) + 1):
        for j in range(len(headers)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#F2F2F2')
            else:
                table[(i, j)].set_facecolor('white')

            # Colorear las variaciones
            if headers[j] in ['1d%', '5d%', '1m%']:  # Columnas de variación
                cell_text = table[(i, j)].get_text().get_text()
                if cell_text.startswith('+'):
                    table[(i, j)].set_text_props(color='green')
                elif cell_text.startswith('-'):
                    table[(i, j)].set_text_props(color='red')

    # Título
    plt.title('COMMODITIES', fontsize=16, fontweight='bold', pad=20)

    # Guardar la imagen
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
    plt.show()

    print(f"Imagen guardada como: {filename}")

# %% [markdown]
# ## Imprimir tabla
# Imprime la tabla en consola de forma clara.

# %%
def format_commodities_table(df):
    """Formatea la tabla para mostrar como en la imagen"""

    if df.empty:
        print("No se pudieron obtener datos de commodities")
        return

    print("COMMODITIES")
    print("=" * 70) # Adjusted width
    print(f"{'Futuros':<15} {'Precio':<10} {'1d%':<8} {'5d%':<8} {'1m%':<8}") # Added 5d%
    print("-" * 70) # Adjusted width

    for _, row in df.iterrows():
        futuros = row['Futuros']

        # Formatear precio según el commodity
        if row['Futuros'] in ['Litio', 'Oro']:
            precio = f"{row['Precio']:.2f}"
        elif row['Futuros'] == 'M. de hierro':
            precio = f"{row['Precio']:.1f}"
        else:
            precio = f"{row['Precio']:.2f}"

        var_1d = f"{row['1d%']:+.2f}%"
        var_5d = f"{row['5d%']:+.2f}%" if not pd.isna(row['5d%']) else 'N/D' # Include 5d variation
        var_1m = f"{row['1m%']:+.1f}%"

        print(f"{futuros:<15} {precio:<10} {var_1d:<8} {var_5d:<8} {var_1m:<8}") # Added 5d%

# %% [markdown]
# ##Ejecutar
# Llama a get_commodities_data.
#
# Muestra por consola con format_commodities_table.
#
# Genera el PNG con create_commodities_image.
#
# Devuelve el DataFrame con los datos.

# %%
# Función principal
def main(fecha_especifica=None):
    """
    Parámetro fecha_especifica: formato 'YYYY-MM-DD' (ej: '2025-07-01')
    Si es None, obtiene datos actuales
    """
    print("Obteniendo datos de commodities...")

    # Obtener datos
    df = get_commodities_data(fecha_especifica)

    if not df.empty:
        # Mostrar tabla formateada en consola
        format_commodities_table(df)

        # Crear imagen PNG
        filename = f"commodities_{fecha_especifica if fecha_especifica else 'actual'}.png"
        create_commodities_image(df, filename)

        return df
    else:
        print("No se pudieron obtener datos de ningún commodity")
        return None

# %% [markdown]
# Ejecutamos

# %%
# Ejecutar el código
if __name__ == "__main__":
    # Para datos actuales (por defecto):
    commodities_data = main()

    # Para una fecha específica, descomenta y modifica esta línea:
    # commodities_data = main('2025-07-01')  # Formato: 'YYYY-MM-DD'
# Out:
# Obteniendo datos de commodities...
# COMMODITIES
# ...
# Futuros         Precio     1d%      5d%      1m%
# ----------------------------------------------------------------------
# Brent           71.69      +2.36%   +4.64%   +6.0%
# M. de hierro    59.8       +0.54%   -1.87%   +12.9%
# Cobre           5.66       +1.11%   -2.38%   +12.5%
# Gas Natural     3.07       +2.84%   -0.13%   -11.1%
# Litio           42.94      -0.74%   -1.22%   +11.8%
# Oro             3326.20    +0.52%   -2.00%   +1.0%
# Café            297.45     -1.41%   -1.29%   -3.0%
# Soja            1008.25    +1.97%   +0.25%   -1.6%
# Imagen guardada como: commodities_actual.png

# %% [markdown]
# # Tasas

# %% [markdown]
# ## Brasil

# %%
def get_brazil_selic_rate():
    """Obtiene la tasa Selic de Brasil desde el Banco Central"""
    try:
        # API del Banco Central de Brasil
        url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.432/dados/ultimos/1?formato=json"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            if data:
                current_rate = float(data[0]['valor'])
                return current_rate
    except Exception as e:
        print(f"Error obteniendo Selic: {e}")

    return 10.75  # Fallback

def get_brazil_selic_historical(days=35):
    """Obtiene datos históricos de la tasa Selic"""
    try:
        # API del Banco Central de Brasil para datos históricos
        end_date = datetime.now()
        start_date = end_date - timedelta(days=days)

        start_str = start_date.strftime('%d/%m/%Y')
        end_str = end_date.strftime('%d/%m/%Y')

        url = f"https://api.bcb.gov.br/dados/serie/bcdata.sgs.432/dados?formato=json&dataInicial={start_str}&dataFinal={end_str}"
        response = requests.get(url, timeout=10)

        if response.status_code == 200:
            data = response.json()
            if len(data) >= 2:
                current_rate = float(data[-1]['valor'])
                rate_30d_ago = float(data[0]['valor'])
                change_pb = (current_rate - rate_30d_ago) * 100
                return current_rate, change_pb
    except Exception as e:
        print(f"Error obteniendo datos históricos Selic: {e}")

    return 10.75, 0

# %% [markdown]
# ## Chile

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import json
from collections import Counter

def get_chile_tpm_rates_from_investing():
    """Scrapea las tasas de interés (actual y anterior) de Chile desde Investing.com"""
    url = "https://es.investing.com/economic-calendar/chilean-interest-rate-decision-492"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Language": "es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3",
        "Accept-Encoding": "gzip, deflate",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1"
    }

    try:
        # Añadir un pequeño delay para evitar detección
        time.sleep(1)

        r = requests.get(url, headers=headers, timeout=10)
        r.raise_for_status()  # Lanza excepción si hay error HTTP

        soup = BeautifulSoup(r.text, "html.parser")

        rates = {'actual': None, 'anterior': None}

        # Estrategia 1: Buscar tabla con estructura típica de calendario económico
        table = soup.find('table', class_=re.compile(r'(genTbl|eventHistoryTable)', re.I))
        if table:
            rows = table.find_all('tr')
            for row in rows:
                cells = row.find_all(['td', 'th'])
                if len(cells) >= 3:
                    # Buscar columnas "Actual" y "Anterior"
                    for i, cell in enumerate(cells):
                        cell_text = cell.get_text(strip=True).lower()
                        if 'actual' in cell_text and i + 1 < len(cells):
                            actual_text = cells[i + 1].get_text(strip=True)
                            rates['actual'] = validate_chile_rate(actual_text)
                        elif 'anterior' in cell_text and i + 1 < len(cells):
                            anterior_text = cells[i + 1].get_text(strip=True)
                            rates['anterior'] = validate_chile_rate(anterior_text)

        # Estrategia 2: Buscar elementos específicos con clases o IDs
        actual_selectors = [
            'span[class*="actual"]',
            'td[class*="actual"]',
            'div[class*="actual"]',
            '.event-value.actual',
            '[data-field="actual"]'
        ]

        anterior_selectors = [
            'span[class*="previous"]',
            'td[class*="previous"]',
            'div[class*="previous"]',
            '.event-value.previous',
            '[data-field="previous"]',
            'span[class*="anterior"]',
            'td[class*="anterior"]'
        ]

        # Buscar tasa actual
        for selector in actual_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True), validate_chile_rate)
                if rate and not rates['actual']:
                    rates['actual'] = rate
                    break

        # Buscar tasa anterior
        for selector in anterior_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True), validate_chile_rate)
                if rate and not rates['anterior']:
                    rates['anterior'] = rate
                    break

        # Estrategia 3: Buscar en el contexto del texto
        text = soup.get_text()

        # Patrones para buscar "Actual: X%" and "Anterior: Y%"
        actual_pattern = r'actual[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'
        anterior_pattern = r'anterior[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'

        if not rates['actual']:
            actual_match = re.search(actual_pattern, text, re.IGNORECASE)
            if actual_match:
                rates['actual'] = validate_chile_rate(actual_match.group(1))

        if not rates['anterior']:
            anterior_match = re.search(anterior_pattern, text, re.IGNORECASE)
            if anterior_match:
                rates['anterior'] = validate_chile_rate(anterior_match.group(1))

        # Estrategia 4: Buscar all rates and use context
        all_rates = []
        matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
        for match in matches:
            rate = validate_chile_rate(match)
            if rate:
                all_rates.append(rate)

        # If we find exactly 2 rates, assume order (actual, anterior)
        if len(all_rates) >= 2 and not rates['actual'] and not rates['anterior']:
            # Order to identify common patterns
            unique_rates = list(set(all_rates))
            if len(unique_rates) >= 2:
                # Heuristics: the most common rate could be the current one
                rate_counts = Counter(all_rates)
                sorted_rates = sorted(rate_counts.items(), key=lambda x: x[1], reverse=True)

                # Take the two most frequent rates
                if len(sorted_rates) >= 2:
                    rates['actual'] = sorted_rates[0][0]
                    rates['anterior'] = sorted_rates[1][0]


        # Show results
        if rates['actual'] or rates['anterior']:
            print("✅ Tasas de Chile encontradas:")
            if rates['actual']:
                print(f"   🇨🇱 Actual: {rates['actual']}%")
            if rates['anterior']:
                print(f"   📈 Anterior: {rates['anterior']}%")
            return rates
        else:
            print("⚠️ No se encontraron las tasas actual y anterior de Chile")
            print("🔍 Contenido parcial del sitio:")
            print(text[:500] + "..." if len(text) > 500 else text)

    except requests.RequestException as e:
        print(f"❌ Error de conexión Chile: {e}")
    except Exception as e:
        print(f"❌ Error inesperado Chile: {e}")

    return None

def extract_rate_from_text(text, validate_func):
    """Extrae una tasa de un texto dado using a validation function"""
    if not text:
        return None

    # Buscar patrones de tasa
    matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%?", text)
    for match in matches:
        rate = validate_func(match)
        if rate:
            return rate
    return None


def validate_chile_rate(rate_string):
    """Valida y convierte una cadena de tasa a float para Chile"""
    try:
        rate = float(rate_string.replace(',', '.'))
        # Verificar que está en un rango razonable para Chile (históricamente entre 0.5% and 11.25%)
        if 0.5 <= rate <= 12.0:
            return rate
        # Si el número es muy pequeño, podría estar en decimales (0.0525 = 5.25%)
        elif 0.005 <= rate <= 0.12:
             return rate * 100
    except:
        pass
    return None

def calculate_basis_points(current_rate, previous_rate):
    """Calcula los puntos básicos entre dos tasas"""
    if current_rate is None or previous_rate is None:
        return None

    # 1 punto básico = 0.01%
    basis_points = (current_rate - previous_rate) * 100
    return round(basis_points, 0)


def get_chile_rate_alternative_sources():
    """Fuentes alternativas para obtener las tasas de interés de Chile"""
    alternative_urls = [
        "https://www.tradingeconomics.com/chile/interest-rate",
        "https://www.investing.com/rates-bonds/chile-interest-rate",
        "https://www.global-rates.com/en/interest-rates/central-banks/chilean-banco-central-de-chile-interest-rate.aspx"
    ]

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }

    for url in alternative_urls:
        try:
            print(f"🔍 Intentando fuente alternativa Chile: {url}")
            time.sleep(1)

            r = requests.get(url, headers=headers, timeout=10)
            soup = BeautifulSoup(r.text, "html.parser")
            text = soup.get_text()

            # Buscar múltiples tasas
            matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
            valid_rates = []
            for match in matches:
                rate = validate_chile_rate(match)
                if rate:
                    valid_rates.append(rate)

            if len(valid_rates) >= 2:
                # Tomar las dos tasas más diferentes (probablemente actual y anterior)
                unique_rates = list(set(valid_rates))
                if len(unique_rates) >= 2:
                    # Ordenar y tomar las dos más probables
                    unique_rates.sort(reverse=True)
                    rates = {
                        'actual': unique_rates[1], # The smaller one could be the current one
                        'anterior': unique_rates[0] # The larger one could be the previous one
                    }
                    print(f"✅ Tasas de Chile encontradas en fuente alternativa:")
                    print(f"   🇨🇱 Actual: {rates['actual']}%")
                    print(f"   📈 Anterior: {rates['anterior']}%")
                    return rates

        except Exception as e:
            print(f"❌ Error en fuente alternativa Chile {url}: {e}")
            continue

    return None


# This function is no longer needed as we are scraping
# def get_chile_tpm_rate():
#     """Obtiene la TPM de Chile desde la API del Banco Central de Chile"""
#     # This function will now be replaced by scraping
#     print("⚠️ Using get_chile_tpm_rates_from_investing instead of BCCh API for current rate.")
#     rates = get_chile_tpm_rates_from_investing()
#     if rates and rates.get('actual'):
#         return rates['actual']
#     return 5.0 # Fallback


def get_chile_tpm_historical():
    """Obtiene datos históricos de la TPM de Chile y calcula el cambio 30d"""
    print("🔄 Obteniendo datos históricos de TPM Chile por scraping...")
    rates = get_chile_tpm_rates_from_investing()

    if rates and rates.get('actual') and rates.get('anterior'):
        current_rate = rates['actual']
        previous_rate = rates['anterior']
        change_pb = calculate_basis_points(current_rate, previous_rate)
        print(f"✅ Cambio TPM Chile calculado por scraping: {change_pb:+.0f}pb")
        return current_rate, change_pb
    else:
        print("⚠️ No se pudieron obtener datos históricos de TPM Chile por scraping. Usando fallback.")
        return 5.0, 0 # Fallback


if __name__ == "__main__":
    print("🇨🇱 Obteniendo tasas de interés de Chile...")
    print("=" * 50)

    # Probar fuente principal
    rates = get_chile_tpm_rates_from_investing()

    # If it doesn't work, try alternative sources
    if not rates or not rates.get('actual') or not rates.get('anterior'):
        print("\n🔄 Probando fuentes alternativas...")
        rates_alt = get_chile_rate_alternative_sources()
        if rates_alt:
            rates = rates_alt

    if rates and rates.get('actual') and rates.get('anterior'):
        actual = rates['actual']
        anterior = rates['anterior']

        print(f"\n🇨🇱 RESUMEN DE TASAS DE INTERÉS - CHILE")
        print("=" * 45)
        print(f"📈 Tasa Anterior: {anterior}%")
        print(f"🇨🇱 Tasa Actual:   {actual}%")

        # Calculate basis points
        basis_points = calculate_basis_points(actual, anterior)
        change_text = format_basis_points_change(basis_points)

        print(f"📉 Cambio: {change_text}")

        # Additional analysis
        if basis_points is not None:
            if basis_points > 0:
                print("💡 Banco Central de Chile SUBIÓ la tasa de interés")
            elif basis_points < 0:
                print("💡 Banco Central de Chile BAJÓ la tasa de interés")
            else:
                print("💡 Banco Central de Chile MANTUVO la tasa de interés")

            # Context of magnitude
            abs_bp = abs(basis_points)
            if abs_bp >= 100:
                print(f"🔥 Cambio SIGNIFICATIVO de {abs_bp} puntos básicos")
            elif abs_bp >= 50:
                print(f"📊 Cambio MODERADO de {abs_bp} puntos básicos")
            elif abs_bp >= 25:
                print(f"📈 Cambio PEQUEÑO de {abs_bp} puntos básicos")
            elif abs_bp > 0:
                print(f"🔍 Cambio MÍNIMO de {abs_bp} puntos básicos")

    else:
        print("\n❌ No se pudieron obtener ambas tasas de interés de Chile")
        print("💡 Sugerencias:")
        print("   - Verificar conexión a internet")
        print("   - El sitio podría tener medidas anti-bot")
        print("   - Intentar más tarde")
        print("   - Considerar usar APIs oficiales del Banco Central")

        # Show partial rates if available
        if rates:
            if rates.get('actual'):
                print(f"   ✅ Tasa actual encontrada: {rates['actual']}%")
            if rates.get('anterior'):
                print(f"   ✅ Tasa anterior encontrada: {rates['anterior']}%")
# Out:
# 🇨🇱 Obteniendo tasas de interés de Chile...
# ...
# ✅ Tasas de Chile encontradas:
#    🇨🇱 Actual: 4.75%
#    📈 Anterior: 5.0%
#
# 🇨🇱 RESUMEN DE TASAS DE INTERÉS - CHILE
# ...
# 📈 Tasa Anterior: 5.0%
# 🇨🇱 Tasa Actual:   4.75%
# 📉 Cambio: -25 pb (bajada)
# 💡 Banco Central de Chile BAJÓ la tasa de interés
# 📈 Cambio PEQUEÑO de 25.0 puntos básicos

# %% [markdown]
# ## México

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import json

def get_mexico_interest_rates_from_investing():
    """Scrapea las tasas de interés (actual y anterior) de Banxico desde Investing.com"""
    url = "https://es.investing.com/economic-calendar/mexican-interest-rate-decision-423"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Language": "es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3",
        "Accept-Encoding": "gzip, deflate",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1"
    }

    try:
        # Añadir un pequeño delay para evitar detección
        time.sleep(1)

        r = requests.get(url, headers=headers, timeout=10)
        r.raise_for_status()  # Lanza excepción si hay error HTTP

        soup = BeautifulSoup(r.text, "html.parser")

        rates = {'actual': None, 'anterior': None}

        # Estrategia 1: Buscar tabla con estructura típica de calendario económico
        table = soup.find('table', class_=re.compile(r'(genTbl|eventHistoryTable)', re.I))
        if table:
            rows = table.find_all('tr')
            for row in rows:
                cells = row.find_all(['td', 'th'])
                if len(cells) >= 3:
                    # Buscar columnas "Actual" y "Anterior"
                    for i, cell in enumerate(cells):
                        cell_text = cell.get_text(strip=True).lower()
                        if 'actual' in cell_text and i + 1 < len(cells):
                            actual_text = cells[i + 1].get_text(strip=True)
                            rates['actual'] = extract_rate_from_text(actual_text)
                        elif 'anterior' in cell_text and i + 1 < len(cells):
                            anterior_text = cells[i + 1].get_text(strip=True)
                            rates['anterior'] = extract_rate_from_text(anterior_text)

        # Estrategia 2: Buscar elementos específicos con clases o IDs
        actual_selectors = [
            'span[class*="actual"]',
            'td[class*="actual"]',
            'div[class*="actual"]',
            '.event-value.actual',
            '[data-field="actual"]'
        ]

        anterior_selectors = [
            'span[class*="previous"]',
            'td[class*="previous"]',
            'div[class*="previous"]',
            '.event-value.previous',
            '[data-field="previous"]',
            'span[class*="anterior"]',
            'td[class*="anterior"]'
        ]

        # Buscar tasa actual
        for selector in actual_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True))
                if rate and not rates['actual']:
                    rates['actual'] = rate
                    break

        # Buscar tasa anterior
        for selector in anterior_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True))
                if rate and not rates['anterior']:
                    rates['anterior'] = rate
                    break

        # Estrategia 3: Buscar en el contexto del texto
        text = soup.get_text()

        # Patrones para buscar "Actual: X%" y "Anterior: Y%"
        actual_pattern = r'actual[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'
        anterior_pattern = r'anterior[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'

        if not rates['actual']:
            actual_match = re.search(actual_pattern, text, re.IGNORECASE)
            if actual_match:
                rates['actual'] = validate_rate(actual_match.group(1))

        if not rates['anterior']:
            anterior_match = re.search(anterior_pattern, text, re.IGNORECASE)
            if anterior_match:
                rates['anterior'] = validate_rate(anterior_match.group(1))

        # Estrategia 4: Buscar todas las tasas y usar contexto
        all_rates = []
        matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
        for match in matches:
            rate = validate_rate(match)
            if rate:
                all_rates.append(rate)

        # Si encontramos exactamente 2 tasas, asumir orden (actual, anterior)
        if len(all_rates) >= 2 and not rates['actual'] and not rates['anterior']:
            # Ordenar para identificar patrones comunes
            unique_rates = list(set(all_rates))
            if len(unique_rates) >= 2:
                # Heurística: la tasa más común podría ser la actual
                from collections import Counter
                rate_counts = Counter(all_rates)
                sorted_rates = sorted(rate_counts.items(), key=lambda x: x[1], reverse=True)

                # Tomar las dos tasas más frecuentes
                if len(sorted_rates) >= 2:
                    rates['actual'] = sorted_rates[0][0]
                    rates['anterior'] = sorted_rates[1][0]

        # Mostrar resultados
        if rates['actual'] or rates['anterior']:
            print("✅ Tasas encontradas:")
            if rates['actual']:
                print(f"   📊 Actual: {rates['actual']}%")
            if rates['anterior']:
                print(f"   📈 Anterior: {rates['anterior']}%")
            return rates
        else:
            print("⚠️ No se encontraron las tasas actual y anterior")
            print("🔍 Contenido parcial del sitio:")
            print(text[:500] + "..." if len(text) > 500 else text)

    except requests.RequestException as e:
        print(f"❌ Error de conexión: {e}")
    except Exception as e:
        print(f"❌ Error inesperado: {e}")

    return None

def extract_rate_from_text(text):
    """Extrae una tasa de un texto dado"""
    if not text:
        return None

    # Buscar patrones de tasa
    matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%?", text)
    for match in matches:
        rate = validate_rate(match)
        if rate:
            return rate
    return None

def validate_rate(rate_string):
    """Valida y convierte una cadena de tasa a float"""
    try:
        rate = float(rate_string.replace(',', '.'))
        # Verificar que está en un rango razonable para México
        if 2.0 <= rate <= 20.0:
            return rate
        # Si el número es muy pequeño, podría estar en decimales (0.08 = 8%)
        elif 0.02 <= rate <= 0.20:
            return rate * 100
    except:
        pass
    return None

def calculate_basis_points(current_rate, previous_rate):
    """Calcula los puntos básicos entre dos tasas"""
    if current_rate is None or previous_rate is None:
        return None

    # 1 punto básico = 0.01%
    basis_points = (current_rate - previous_rate) * 100
    return round(basis_points, 0)

def format_basis_points_change(basis_points):
    """Formatea el cambio en puntos básicos"""
    if basis_points is None:
        return "N/A"

    if basis_points > 0:
        return f"+{int(basis_points)} pb (subida)"
    elif basis_points < 0:
        return f"{int(basis_points)} pb (bajada)"
    else:
        return "0 pb (sin cambio)"

def get_mexico_rate_alternative_sources():
    """Fuentes alternativas para obtener las tasas de interés de México"""
    alternative_urls = [
        "https://www.tradingeconomics.com/mexico/interest-rate",
        "https://www.investing.com/rates-bonds/mexico-interest-rate",
        "https://www.global-rates.com/en/interest-rates/central-banks/mexican-banxico-overnight-target-rate.aspx"
    ]

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }

    for url in alternative_urls:
        try:
            print(f"🔍 Intentando fuente alternativa: {url}")
            time.sleep(1)

            r = requests.get(url, headers=headers, timeout=10)
            soup = BeautifulSoup(r.text, "html.parser")
            text = soup.get_text()

            # Buscar múltiples tasas
            matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
            valid_rates = []
            for match in matches:
                rate = validate_rate(match)
                if rate:
                    valid_rates.append(rate)

            if len(valid_rates) >= 2:
                # Tomar las dos tasas más diferentes (probablemente actual y anterior)
                unique_rates = list(set(valid_rates))
                if len(unique_rates) >= 2:
                    # Ordenar y tomar las dos más probables
                    unique_rates.sort(reverse=True)
                    rates = {
                        'actual': unique_rates[1],  # La menor podría ser la actual
                        'anterior': unique_rates[0]  # La mayor podría ser la anterior
                    }
                    print(f"✅ Tasas encontradas en fuente alternativa:")
                    print(f"   📊 Actual: {rates['actual']}%")
                    print(f"   📈 Anterior: {rates['anterior']}%")
                    return rates

        except Exception as e:
            print(f"❌ Error en fuente alternativa {url}: {e}")
            continue

    return None

if __name__ == "__main__":
    print("🇲🇽 Obteniendo tasas de interés de Banxico...")
    print("=" * 50)

    # Probar fuente principal
    rates = get_mexico_interest_rates_from_investing()

    # Si no funciona, probar fuentes alternativas
    if not rates or not rates.get('actual') or not rates.get('anterior'):
        print("\n🔄 Probando fuentes alternativas...")
        rates_alt = get_mexico_rate_alternative_sources()
        if rates_alt:
            rates = rates_alt

    if rates and rates.get('actual') and rates.get('anterior'):
        actual = rates['actual']
        anterior = rates['anterior']

        print(f"\n📊 RESUMEN DE TASAS DE INTERÉS")
        print("=" * 40)
        print(f"📈 Tasa Anterior: {anterior}%")
        print(f"📊 Tasa Actual:   {actual}%")

        # Calcular puntos básicos
        basis_points = calculate_basis_points(actual, anterior)
        change_text = format_basis_points_change(basis_points)

        print(f"📉 Cambio: {change_text}")

        # Análisis adicional
        if basis_points is not None:
            if basis_points > 0:
                print("💡 Banxico SUBIÓ la tasa de interés")
            elif basis_points < 0:
                print("💡 Banxico BAJÓ la tasa de interés")
            else:
                print("💡 Banxico MANTUVO la tasa de interés")

            # Contexto de magnitud
            abs_bp = abs(basis_points)
            if abs_bp >= 100:
                print(f"🔥 Cambio SIGNIFICATIVO de {abs_bp} puntos básicos")
            elif abs_bp >= 50:
                print(f"📊 Cambio MODERADO de {abs_bp} puntos básicos")
            elif abs_bp >= 25:
                print(f"📈 Cambio PEQUEÑO de {abs_bp} puntos básicos")
            elif abs_bp > 0:
                print(f"🔍 Cambio MÍNIMO de {abs_bp} puntos básicos")

    else:
        print("\n❌ No se pudieron obtener ambas tasas de interés")
        print("💡 Sugerencias:")
        print("   - Verificar conexión a internet")
        print("   - El sitio podría tener medidas anti-bot")
        print("   - Intentar más tarde")
        print("   - Considerar usar APIs oficiales como la de Banxico")

        # Mostrar tasas parciales si las hay
        if rates:
            if rates.get('actual'):
                print(f"   ✅ Tasa actual encontrada: {rates['actual']}%")
            if rates.get('anterior'):
                print(f"   ✅ Tasa anterior encontrada: {rates['anterior']}%")
# Out:
# 🇲🇽 Obteniendo tasas de interés de Banxico...
# ...
# ✅ Tasas encontradas:
#    📊 Actual: 8.0%
#    📈 Anterior: 8.5%
#
# 📊 RESUMEN DE TASAS DE INTERÉS
# ...
# 📈 Tasa Anterior: 8.5%
# 📊 Tasa Actual:   8.0%
# 📉 Cambio: -50 pb (bajada)
# 💡 Banxico BAJÓ la tasa de interés
# 📊 Cambio MODERADO de 50.0 puntos básicos

# %% [markdown]
# ## Colombia

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import json
from collections import Counter

def get_colombia_interest_rates_from_investing():
    """Scrapea las tasas de interés (actual y anterior) de Colombia desde Investing.com"""
    url = "https://es.investing.com/economic-calendar/colombian-interest-rate-decision-497"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Language": "es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3",
        "Accept-Encoding": "gzip, deflate",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1"
    }

    try:
        # Añadir un pequeño delay para evitar detección
        time.sleep(1)

        r = requests.get(url, headers=headers, timeout=10)
        r.raise_for_status()  # Lanza excepción si hay error HTTP

        soup = BeautifulSoup(r.text, "html.parser")

        rates = {'actual': None, 'anterior': None}

        # Estrategia 1: Buscar tabla con estructura típica de calendario económico
        table = soup.find('table', class_=re.compile(r'(genTbl|eventHistoryTable)', re.I))
        if table:
            rows = table.find_all('tr')
            for row in rows:
                cells = row.find_all(['td', 'th'])
                if len(cells) >= 3:
                    # Buscar columnas "Actual" y "Anterior"
                    for i, cell in enumerate(cells):
                        cell_text = cell.get_text(strip=True).lower()
                        if 'actual' in cell_text and i + 1 < len(cells):
                            actual_text = cells[i + 1].get_text(strip=True)
                            rates['actual'] = extract_rate_from_text(actual_text)
                        elif 'anterior' in cell_text and i + 1 < len(cells):
                            anterior_text = cells[i + 1].get_text(strip=True)
                            rates['anterior'] = extract_rate_from_text(anterior_text)

        # Estrategia 2: Buscar elementos específicos con clases o IDs
        actual_selectors = [
            'span[class*="actual"]',
            'td[class*="actual"]',
            'div[class*="actual"]',
            '.event-value.actual',
            '[data-field="actual"]'
        ]

        anterior_selectors = [
            'span[class*="previous"]',
            'td[class*="previous"]',
            'div[class*="previous"]',
            '.event-value.previous',
            '[data-field="previous"]',
            'span[class*="anterior"]',
            'td[class*="anterior"]'
        ]

        # Buscar tasa actual
        for selector in actual_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True))
                if rate and not rates['actual']:
                    rates['actual'] = rate
                    break

        # Buscar tasa anterior
        for selector in anterior_selectors:
            elements = soup.select(selector)
            for element in elements:
                rate = extract_rate_from_text(element.get_text(strip=True))
                if rate and not rates['anterior']:
                    rates['anterior'] = rate
                    break

        # Estrategia 3: Buscar en el contexto del texto
        text = soup.get_text()

        # Patrones para buscar "Actual: X%" y "Anterior: Y%"
        actual_pattern = r'actual[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'
        anterior_pattern = r'anterior[:\s]*(\d{1,2}[.,]\d{1,2})\s*%'

        if not rates['actual']:
            actual_match = re.search(actual_pattern, text, re.IGNORECASE)
            if actual_match:
                rates['actual'] = validate_colombia_rate(actual_match.group(1))

        if not rates['anterior']:
            anterior_match = re.search(anterior_pattern, text, re.IGNORECASE)
            if anterior_match:
                rates['anterior'] = validate_colombia_rate(anterior_match.group(1))

        # Estrategia 4: Buscar todas las tasas y usar contexto
        all_rates = []
        matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
        for match in matches:
            rate = validate_colombia_rate(match)
            if rate:
                all_rates.append(rate)

        # Si encontramos exactamente 2 tasas, asumir orden (actual, anterior)
        if len(all_rates) >= 2 and not rates['actual'] and not rates['anterior']:
            # Ordenar para identificar patrones comunes
            unique_rates = list(set(all_rates))
            if len(unique_rates) >= 2:
                # Heurística: la tasa más común podría ser la actual
                rate_counts = Counter(all_rates)
                sorted_rates = sorted(rate_counts.items(), key=lambda x: x[1], reverse=True)

                # Tomar las dos tasas más frecuentes
                if len(sorted_rates) >= 2:
                    rates['actual'] = sorted_rates[0][0]
                    rates['anterior'] = sorted_rates[1][0]

        # Mostrar resultados
        if rates['actual'] or rates['anterior']:
            print("✅ Tasas de Colombia encontradas:")
            if rates['actual']:
                print(f"   🇨🇴 Actual: {rates['actual']}%")
            if rates['anterior']:
                print(f"   📈 Anterior: {rates['anterior']}%")
            return rates
        else:
            print("⚠️ No se encontraron las tasas actual y anterior de Colombia")
            print("🔍 Contenido parcial del sitio:")
            print(text[:500] + "..." if len(text) > 500 else text)

    except requests.RequestException as e:
        print(f"❌ Error de conexión Colombia: {e}")
    except Exception as e:
        print(f"❌ Error inesperado Colombia: {e}")

    return None

def extract_rate_from_text(text):
    """Extrae una tasa de un texto dado"""
    if not text:
        return None

    # Buscar patrones de tasa
    matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%?", text)
    for match in matches:
        rate = validate_colombia_rate(match)
        if rate:
            return rate
    return None

def validate_colombia_rate(rate_string):
    """Valida y convierte una cadena de tasa a float para Colombia"""
    try:
        rate = float(rate_string.replace(',', '.'))
        # Verificar que está en un rango razonable para Colombia (históricamente entre 1% y 15%)
        if 1.0 <= rate <= 15.0:
            return rate
        # Si el número es muy pequeño, podría estar en decimales (0.09 = 9%)
        elif 0.01 <= rate <= 0.15:
            return rate * 100
    except:
        pass
    return None

def calculate_basis_points(current_rate, previous_rate):
    """Calcula los puntos básicos entre dos tasas"""
    if current_rate is None or previous_rate is None:
        return None

    # 1 punto básico = 0.01%
    basis_points = (current_rate - previous_rate) * 100
    return round(basis_points, 0)

def format_basis_points_change(basis_points):
    """Formatea el cambio en puntos básicos"""
    if basis_points is None:
        return "N/A"

    if basis_points > 0:
        return f"+{int(basis_points)} pb (subida)"
    elif basis_points < 0:
        return f"{int(basis_points)} pb (bajada)"
    else:
        return "0 pb (sin cambio)"

def get_colombia_rate_alternative_sources():
    """Fuentes alternativas para obtener las tasas de interés de Colombia"""
    alternative_urls = [
        "https://www.tradingeconomics.com/colombia/interest-rate",
        "https://www.investing.com/rates-bonds/colombia-interest-rate",
        "https://www.global-rates.com/en/interest-rates/central-banks/colombian-banco-de-la-republica-interest-rate.aspx"
    ]

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }

    for url in alternative_urls:
        try:
            print(f"🔍 Intentando fuente alternativa Colombia: {url}")
            time.sleep(1)

            r = requests.get(url, headers=headers, timeout=10)
            soup = BeautifulSoup(r.text, "html.parser")
            text = soup.get_text()

            # Buscar múltiples tasas
            matches = re.findall(r"(\d{1,2}[.,]\d{1,2})\s*%", text)
            valid_rates = []
            for match in matches:
                rate = validate_colombia_rate(match)
                if rate:
                    valid_rates.append(rate)

            if len(valid_rates) >= 2:
                # Tomar las dos tasas más diferentes (probablemente actual y anterior)
                unique_rates = list(set(valid_rates))
                if len(unique_rates) >= 2:
                    # Ordenar y tomar las dos más probables
                    unique_rates.sort(reverse=True)
                    rates = {
                        'actual': unique_rates[1],  # La menor podría ser la actual
                        'anterior': unique_rates[0]  # La mayor podría ser la anterior
                    }
                    print(f"✅ Tasas de Colombia encontradas en fuente alternativa:")
                    print(f"   🇨🇴 Actual: {rates['actual']}%")
                    print(f"   📈 Anterior: {rates['anterior']}%")
                    return rates

        except Exception as e:
            print(f"❌ Error en fuente alternativa Colombia {url}: {e}")
            continue

    return None

if __name__ == "__main__":
    print("🇨🇴 Obteniendo tasas de interés de Colombia...")
    print("=" * 50)

    # Probar fuente principal
    rates = get_colombia_interest_rates_from_investing()

    # Si no funciona, probar fuentes alternativas
    if not rates or not rates.get('actual') or not rates.get('anterior'):
        print("\n🔄 Probando fuentes alternativas...")
        rates_alt = get_colombia_rate_alternative_sources()
        if rates_alt:
            rates = rates_alt

    if rates and rates.get('actual') and rates.get('anterior'):
        actual = rates['actual']
        anterior = rates['anterior']

        print(f"\n🇨🇴 RESUMEN DE TASAS DE INTERÉS - COLOMBIA")
        print("=" * 45)
        print(f"📈 Tasa Anterior: {anterior}%")
        print(f"🇨🇴 Tasa Actual:   {actual}%")

        # Calcular puntos básicos
        basis_points = calculate_basis_points(actual, anterior)
        change_text = format_basis_points_change(basis_points)

        print(f"📉 Cambio: {change_text}")

        # Análisis adicional
        if basis_points is not None:
            if basis_points > 0:
                print("💡 Banco de la República SUBIÓ la tasa de interés")
            elif basis_points < 0:
                print("💡 Banco de la República BAJÓ la tasa de interés")
            else:
                print("💡 Banco de la República MANTUVO la tasa de interés")

            # Contexto de magnitud
            abs_bp = abs(basis_points)
            if abs_bp >= 100:
                print(f"🔥 Cambio SIGNIFICATIVO de {abs_bp} puntos básicos")
            elif abs_bp >= 50:
                print(f"📊 Cambio MODERADO de {abs_bp} puntos básicos")
            elif abs_bp >= 25:
                print(f"📈 Cambio PEQUEÑO de {abs_bp} puntos básicos")
            elif abs_bp > 0:
                print(f"🔍 Cambio MÍNIMO de {abs_bp} puntos básicos")

    else:
        print("\n❌ No se pudieron obtener ambas tasas de interés de Colombia")
        print("💡 Sugerencias:")
        print("   - Verificar conexión a internet")
        print("   - El sitio podría tener medidas anti-bot")
        print("   - Intentar más tarde")
        print("   - Considerar usar APIs oficiales del Banco de la República")

        # Mostrar tasas parciales si las hay
        if rates:
            if rates.get('actual'):
                print(f"   ✅ Tasa actual encontrada: {rates['actual']}%")
            if rates.get('anterior'):
                print(f"   ✅ Tasa anterior encontrada: {rates['anterior']}%")
# Out:
# 🇨🇴 Obteniendo tasas de interés de Colombia...
# ...
# ✅ Tasas de Colombia encontradas:
#    🇨🇴 Actual: 9.25%
#    📈 Anterior: 9.25%
#
# 🇨🇴 RESUMEN DE TASAS DE INTERÉS - COLOMBIA
# ...
# 📈 Tasa Anterior: 9.25%
# 🇨🇴 Tasa Actual:   9.25%
# 📉 Cambio: 0 pb (sin cambio)
# 💡 Banco de la República MANTUVO la tasa de interés

# %% [markdown]
# ## Estados Unidos

# %%
from fredapi import Fred
from datetime import datetime, timedelta

FRED_API_KEY = "ea2f25d47acda8a93c25bcc69dd3e414 "  # 🔒 <<-- Replace with your real FRED API Key -->>
fred = Fred(api_key=FRED_API_KEY)

def get_us_fed_funds_rate():
    """Obtiene la última tasa efectiva de los fondos federales desde FRED"""
    try:
        data = fred.get_series("FEDFUNDS")
        latest_rate = data.dropna().iloc[-1]
        print(f"✅ Última tasa Fed Funds: {latest_rate:.2f}%")
        return float(latest_rate)
    except Exception as e:
        print(f"❌ Error obteniendo Fed Funds desde FRED: {e}")
        return 5.25  # fallback

def get_us_fed_historical():
    """Calcula el cambio en la tasa de fondos federales en los últimos 30 días"""
    try:
        end_date = datetime.today()
        start_date = end_date - timedelta(days=35)

        data = fred.get_series("FEDFUNDS", start_date, end_date).dropna()

        if len(data) >= 2:
            current = data.iloc[-1]
            # Find the rate approximately 30 days ago
            past_date = end_date - timedelta(days=30)
            past_data = data[data.index <= past_date]

            if not past_data.empty:
                past = past_data.iloc[-1]
                change_pb = (current - past) * 100
                print(f"✅ Fed Funds actual: {current:.2f}% | Cambio 30d: {change_pb:+.0f}pb")
                return float(current), change_pb
            else:
                print("⚠️ Insufficient historical data for 30d change calculation.")
                return float(current), 0 # Return current rate with 0 change if not enough history

    except Exception as e:
        print(f"❌ Error histórico Fed Funds desde FRED: {e}")

    return None, None  # Return None if data fetching fails

# %% [markdown]
# ## Función central de obtención

# %% [markdown]
# Llama a las funciones anteriores para obtener tasas actuales y cambios para:
#
# Selic Brasil
#
# TPM Chile
#
# Banxico México
#
# Tasa Colombia
#
# Fed Funds (EEUU)
#
# Agrega manualmente bonos soberanos (BRZ 37, MEX 40, CHILE 41) y tasas USD (^TNX).
#
# Devuelve un DataFrame con columnas:

# %%
def get_monetary_policy_data(fecha_especifica=None):
    """Obtiene datos de política monetaria con API automatizada para Chile"""

    print("Obteniendo tasas de política monetaria...")
    print("🔄 Chile: Consultando API del Banco Central...")

    # Obtener tasas actuales y cambios históricos
    try:
        selic_rate, selic_change = get_brazil_selic_historical()
    except:
        selic_rate, selic_change = 10.75, 0

    try:
        tpm_rate, tpm_change = get_chile_tpm_historical()  # Ahora automatizado
    except:
        tpm_rate, tpm_change = 5.0, 0

    try:
        # Usar el scraping para obtener tasas de México
        rates = get_mexico_interest_rates_from_investing()
        if rates and rates.get('actual') and rates.get('anterior'):
            banxico_rate = rates['actual']
            banxico_change = calculate_basis_points(rates['actual'], rates['anterior'])
            print(f"✅ México: Datos obtenidos por scraping - Actual: {banxico_rate}%, Cambio: {banxico_change} pb")
        else:
            # Fallback a función histórica si el scraping falla
            banxico_rate, banxico_change = get_mexico_banxico_historical()
    except:
        # Fallback final con valores por defecto
        banxico_rate, banxico_change = 8.0, -50

    try:
        # Usar el scraping para obtener tasas de Colombia
        rates = get_colombia_interest_rates_from_investing()
        if rates and rates.get('actual') and rates.get('anterior'):
            colombia_rate = rates['actual']
            colombia_change = calculate_basis_points(rates['actual'], rates['anterior'])
            print(f"✅ Colombia: Datos obtenidos por scraping - Actual: {colombia_rate}%, Cambio: {colombia_change} pb")
        else:
            # Fallback a función histórica si el scraping falla
            colombia_rate, colombia_change = get_colombia_historical()
    except:
        # Fallback final con valores por defecto
        colombia_rate, colombia_change = 9.25, 0

    try:
        fed_rate, fed_change = get_us_fed_historical()
    except:
        fed_rate, fed_change = 5.25, 0

    # Datos actualizados
    monetary_data = {
        'Selic Brasil': {'rate': selic_rate, 'change_30d': selic_change},
        'TPM Chile': {'rate': tpm_rate, 'change_30d': tpm_change},
        'Tasa Ref Méx': {'rate': banxico_rate, 'change_30d': banxico_change},
        'Tasa Ref Col': {'rate': colombia_rate, 'change_30d': colombia_change},
        'Fed Funds': {'rate': fed_rate, 'change_30d': fed_change}
    }

    # Bonos soberanos (mantener datos manuales)
    sovereign_bonds = {
        'BRZ 37': {'rate': 6.58, 'change_30d': 5.63},
        'MEX 40': {'rate': 5.85, 'change_30d': 4.12},
        'CHILE 41': {'rate': 4.95, 'change_30d': 3.28}
    }

    results = []

    # Agregar datos de política monetaria
    for name, data in monetary_data.items():
        results.append({
            'Instrumento': name,
            'Spot (%)': data['rate'],
            '30d (pb)': data['change_30d'],
            'Tipo': 'Política Monetaria'
        })

    # Agregar bonos soberanos
    for name, data in sovereign_bonds.items():
        results.append({
            'Instrumento': name,
            'Spot (%)': data['rate'],
            '30d (pb)': data['change_30d'],
            'Tipo': 'Bonos Soberanos'
        })

    # Agregar tasa USD de referencia
    try:
        ticker = yf.Ticker('^TNX')
        hist = ticker.history(period='35d')
        if len(hist) >= 30:
            us_current = hist['Close'].iloc[-1]
            us_past = hist['Close'].iloc[-30]
            us_change = (us_current - us_past) * 100
        else:
            us_current = 4.50
            us_change = 0
    except:
        us_current = 4.50
        us_change = 0

    results.append({
        'Instrumento': 'Tasas USD',
        'Spot (%)': us_current,
        '30d (pb)': us_change,
        'Tipo': 'Tasas USD'
    })

    print("✅ Datos actualizados")
    print(f"  Chile TPM: {tpm_rate}% (automático desde BCCh)")
    print(f"  México: {banxico_rate}% (manual)")

    return pd.DataFrame(results)

# %% [markdown]
# ## Formato de tabla

# %% [markdown]
# Muestra la tabla con:
#
# Emojis según cambio (📈, 📉, ➡️)
#
# Distinción entre datos automatizados (🤖) y manuales (📝)
#
# Agrupación por tipo de instrumento

# %%
def format_monetary_policy_table(df):
    """Formatea la tabla con datos actualizados"""

    if df.empty:
        print("No se pudieron obtener datos de política monetaria")
        return

    print("\n" + "="*80)
    print("   POLÍTICA MONETARIA")
    print("="*80)

    # Filter out the 'Fed Funds' and 'Tasas USD' rows
    df_filtered = df[(df['Instrumento'] != 'Fed Funds') & (df['Instrumento'] != 'Tasas USD')].copy()

    # Política Monetaria
    pol_monetaria = df_filtered[df_filtered['Tipo'] == 'Política Monetaria']
    if not pol_monetaria.empty:
        print(f"{'INSTRUMENTO':<20} {'SPOT (%)':<12} {'CAMBIO 30D (pb)':<15} {'ESTADO':<10}")
        print("-" * 80)

        for _, row in pol_monetaria.iterrows():
            instrumento = row['Instrumento']
            spot = f"{row['Spot (%)']:.2f}%"
            change_30d_val = row['30d (pb)'] # Get the numerical value
            # Format the change, showing "0pb" if the value is very close to zero
            change_30d_str = f"{change_30d_val:+.0f}pb" if abs(change_30d_val) > 0.001 else "0pb"


            # Indicar estado de la tasa
            if change_30d_val > 0:
                estado = "📈 SUBIÓ"
            elif change_30d_val < 0:
                estado = "📉 BAJÓ"
            else:
                estado = "➡️ ESTABLE"

            # Indicador de automatización
            if "Chile" in instrumento:
                indicator = "🤖"  # Automatizado
            elif "Brasil" in instrumento:
                indicator = "🤖"  # Automatizado
            else:
                indicator = "📝"  # Manual

            print(f"{indicator} {instrumento:<18} {spot:<12} {change_30d_str:<15} {estado:<10}")

    # Bonos Soberanos
    bonos_soberanos = df_filtered[df_filtered['Tipo'] == 'Bonos Soberanos']
    tasas_usd = df_filtered[df_filtered['Tipo'] == 'Tasas USD'] # This will now be empty after filtering

    if not bonos_soberanos.empty: # Only print if there are sovereign bonds
        print("\n" + "="*80)
        print("   BONOS SOBERANOS")
        print("="*80)
        # Removed the loop for printing sovereign bond rows, as they are already removed from the DataFrame

    if not tasas_usd.empty: # This block will likely not execute due to the filter
        print("\n" + "="*80)
        print("   TASAS USD REFERENCIA")
        print("="*80)

        for _, row in tasas_usd.iterrows():
            spot = f"{row['Spot (%)']:.2f}%"
            change_30d_val = row['30d (pb)'] # Get the numerical value
            # Format the change, showing "0pb" if the value is very close to zero
            change_30d_str = f"{change_30d_val:+.0f}pb" if abs(change_30d_val) > 0.001 else "0pb"


            if change_30d_val > 0:
                estado = "📈 SUBIÓ"
            elif change_30d_val < 0:
                estado = "📉 BAJÓ"
            else:
                estado = "➡️ ESTABLE"

            print(f"🔄 {row['Instrumento']:<18} {spot:<12} {change_30d_str:<15} {estado:<10}")

    print("\n" + "="*80)
    print("🤖 = Automatizado | 📝 = Manual | 🔄 = Actualizado | 📈 = Bonos")
    print("📈 = Subió | 📉 = Bajó | ➡️ = Estable")
    print("pb = puntos básicos (1% = 100pb)")
    print("🔗 Fuentes: Brasil (BCB), Chile (BCCh API), México (Banxico), Colombia (BanRep)")
    print("="*80)

# %% [markdown]
# ## Crear imagen

# %%
def create_monetary_policy_image(df, filename='pol_monetaria_automatizada.png'):
    """Crea imagen con datos automatizados"""

    if df.empty:
        print("No se puede crear imagen sin datos")
        return

    # Configurar la figura
    fig, ax = plt.subplots(figsize=(6, 3))
    ax.axis('tight')
    ax.axis('off')

    # Filter out the 'Fed Funds' and 'Tasas USD' rows
    df_filtered = df[(df['Instrumento'] != 'Fed Funds') & (df['Instrumento'] != 'Tasas USD')].copy()

    # Separar por tipos
    pol_monetaria = df_filtered[df_filtered['Tipo'] == 'Política Monetaria']
    bonos_soberanos = df_filtered[df_filtered['Tipo'] == 'Bonos Soberanos'] # Keep this line to filter, but won't be used for display
    tasas_usd = df_filtered[df_filtered['Tipo'] == 'Tasas USD'] # This will now be empty after filtering

    # Prepare data for the table - only include Policy and USD rates
    table_data = []

    # Section: Monetary Policy
    if not pol_monetaria.empty:
        for _, row in pol_monetaria.iterrows():
            spot = f"{row['Spot (%)']:.2f}%"
            change_30d = f"{row['30d (pb)']:+.0f}pb" if row['30d (pb)'] != 0 else "0pb"

            # Add visual indicator of change
            if row['30d (pb)'] > 0:
                trend = "⬆️"
            elif row['30d (pb)'] < 0:
                trend = "⬇️"
            else:
                trend = "➡️"

            table_data.append([
                row['Instrumento'],
                spot,
                change_30d,
                trend
            ])

    # Separador visual (only if both sections exist)
#    if not pol_monetaria.empty and not tasas_usd.empty: # This condition will likely not be met
#        table_data.append(['─' * 25, '─' * 10, '─' * 15, '─' * 5])


    # Section: USD Rates (This section will likely be empty after filtering)
    if not tasas_usd.empty:
        for _, row in tasas_usd.iterrows():
            spot = f"{row['Spot (%)']:.2f}%"
            change_30d = f"{row['30d (pb)']:+.0f}pb" if row['30d (pb)'] != 0 else "0pb"

            if row['30d (pb)'] > 0:
                trend = "⬆️"
            elif row['30d (pb)'] < 0:
                trend = "⬇️"
            else:
                trend = "➡️"

            table_data.append([
                row['Instrumento'],
                spot,
                change_30d,
                trend
            ])


    # Create the table
    table = ax.table(cellText=table_data,
                    colLabels=['Instrumento', 'Spot (%)', 'Cambio 30d (pb)', 'Tendencia'],
                    cellLoc='center',
                    loc='center',
                    colWidths=[0.4, 0.2, 0.25, 0.15])

    # Style the table
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1.2, 2.8)

    # Style the header
    for i in range(4):
        table[(0, i)].set_facecolor('#000080')
        table[(0, i)].set_text_props(weight='bold', color='white')

    # Style the rows
    for i in range(1, len(table_data) + 1):
        for j in range(4):
            if '─' in str(table_data[i-1][0]):  # Separator row
                table[(i, j)].set_facecolor('#E8E8E8')
                table[(i, j)].set_text_props(weight='bold', color='gray')
            elif 'Fed Funds' in str(table_data[i-1][0]) or 'Tasas USD' in str(table_data[i-1][0]): # This condition will likely not be met
                table[(i, j)].set_facecolor('#A23B72') # Keep this style for Fed Funds now categorized under Tasas USD
                table[(i, j)].set_text_props(color='white', weight='bold')
            elif 'BRZ' in str(table_data[i-1][0]) or 'MEX' in str(table_data[i-1][0]) or 'CHILE' in str(table_data[i-1][0]): # This coloring might still apply if data exists, but the rows won't be added
                table[(i, j)].set_facecolor('#F18F01')
                table[(i, j)].set_text_props(color='white', weight='bold')
            elif i % 2 == 0:
                table[(i, j)].set_facecolor('#F5F5F5')
            else:
                table[(i, j)].set_facecolor('white')

    # Title with timestamp
    current_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    plt.title(f'POLÍTICA MONETARIA',
              fontsize=16, fontweight='bold', pad=30)

    # Notes
#    plt.figtext(0.5, 0.05, '🤖 Chile TPM: Automatizado desde BCCh API | México: Manual 8.0%',
#                ha='center', fontsize=11, weight='bold', color='green')
#    plt.figtext(0.5, 0.02, '⬆️⬇️➡️ = Subió/Bajó/Estable vs 30 días | pb = puntos básicos',
#                ha='center', fontsize=10, style='italic', color='blue')

    # Save the image
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
    plt.show()

    print(f"✅ Imagen guardada como: {filename}")

# %% [markdown]
# ## Ejecución

# %%
def main(fecha_especifica=None):
    """Función principal con Chile automatizado"""
    print("🚀 Iniciando obtención de datos...")
    print("🤖 Chile TPM: Automatizado desde API BCCh")
    print("📝 México: 8.0% (manual)") # Keep this as is for now based on previous discussion
    print("📝 Colombia: 9.25% (manual)") # Keep this as is for now based on previous discussion
    print("🔄 Calculando cambios en puntos básicos...")

    # Obtener tasas actuales y cambios históricos
    try:
        selic_rate, selic_change = get_brazil_selic_historical()
    except:
        selic_rate, selic_change = 10.75, 0

    try:
        tpm_rate, tpm_change = get_chile_tpm_historical()  # Now automated
    except:
        tpm_rate, tpm_change = 5.0, 0

    # Use the scraping functions for Mexico and Colombia
    rates_mexico = get_mexico_interest_rates_from_investing()
    if rates_mexico and rates_mexico.get('actual') and rates_mexico.get('anterior'):
        banxico_rate = rates_mexico['actual']
        banxico_change = calculate_basis_points(rates_mexico['actual'], rates_mexico['anterior'])
        print(f"✅ México: Datos obtenidos por scraping - Actual: {banxico_rate}%, Cambio: {banxico_change} pb")
    else:
        # Fallback if scraping fails
        print("⚠️ México: Scraping failed, using fallback values.")
        banxico_rate, banxico_change = 8.0, -50 # Fallback values

    rates_colombia = get_colombia_interest_rates_from_investing()
    if rates_colombia and rates_colombia.get('actual') and rates_colombia.get('anterior'):
        colombia_rate = rates_colombia['actual']
        colombia_change = calculate_basis_points(rates_colombia['actual'], rates_colombia['anterior'])
        print(f"✅ Colombia: Datos obtenidos por scraping - Actual: {colombia_rate}%, Cambio: {colombia_change} pb")
    else:
        # Fallback if scraping fails
        print("⚠️ Colombia: Scraping failed, using fallback values.")
        colombia_rate, colombia_change = 9.25, 0 # Fallback values

    # Get US Fed Funds rate and change - REMOVED FROM THIS SECTION
    # fed_rate, fed_change = get_us_fed_historical()
    # if fed_rate is None:
    #     print("❌ US Fed Funds data could not be obtained, using fallback values.")
    #     fed_rate, fed_change = 5.26, 0 # Fallback if FRED API fails

    # Data structure for monetary policy instruments (excluding Fed Funds)
    monetary_data = {
        'Selic Brasil': {'rate': selic_rate, 'change_30d': selic_change},
        'TPM Chile': {'rate': tpm_rate, 'change_30d': tpm_change},
        'Tasa Ref Méx': {'rate': banxico_rate, 'change_30d': banxico_change},
        'Tasa Ref Col': {'rate': colombia_rate, 'change_30d': colombia_change},
        # 'Fed Funds': {'rate': fed_rate, 'change_30d': fed_change} # Removed
    }

    # Bonos soberanos (maintain manual data) - REMOVED IN PREVIOUS STEP
    # sovereign_bonds = {
    #     'BRZ 37': {'rate': 6.58, 'change_30d': 5.63},
    #     'MEX 40': {'rate': 5.85, 'change_30d': 4.12},
    #     'CHILE 41': {'rate': 4.95, 'change_30d': 3.28}
    # }

    results = []

    # Add monetary policy data
    for name, data in monetary_data.items():
         # Ensure rate and change are not None before appending
        if data['rate'] is not None and data['change_30d'] is not None:
            results.append({
                'Instrumento': name,
                'Spot (%)': data['rate'],
                '30d (pb)': data['change_30d'],
                'Tipo': 'Política Monetaria'
            })
        else:
            print(f"⚠️ Skipping {name} due to missing data.")


    # Add sovereign bonds - REMOVED IN PREVIOUS STEP
    # for name, data in sovereign_bonds.items():
    #     results.append({
    #         'Instrumento': name,
    #         'Spot (%)': data['rate'],
    #         '30d (pb)': data['change_30d'],
    #         'Tipo': 'Bonos Soberanos'
    #     })

    # Add USD reference rates
    try:
        # Fetch ^TNX data
        ticker = yf.Ticker('^TNX')
        hist = ticker.history(period='35d')
        if len(hist) >= 30:
            us_current = hist['Close'].iloc[-1]
            us_past = hist['Close'].iloc[-30]
            us_change = (us_current - us_past) * 100
        else:
            us_current = 4.50
            us_change = 0
            print("⚠️ Insufficient historical data for ^TNX 30d change calculation.")

        results.append({
            'Instrumento': 'Tasas USD',
            'Spot (%)': us_current,
            '30d (pb)': us_change,
            'Tipo': 'Tasas USD'
        })
    except Exception as e:
        print(f"❌ Error obtaining ^TNX data: {e}")
        print("⚠️ Skipping Tasas USD due to data error.")


    df = pd.DataFrame(results)

    # Filter out rows where 'Spot (%)' is None or NaN
    df = df.dropna(subset=['Spot (%)']).reset_index(drop=True)
    # Also filter out the 'Fed Funds' row BEFORE passing to formatting functions
    df_filtered_for_display = df[df['Instrumento'] != 'Fed Funds'].reset_index(drop=True)


    if not df_filtered_for_display.empty:
        # Mostrar tabla formateada en consola
        format_monetary_policy_table(df_filtered_for_display)

        # Crear imagen PNG
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f"pol_monetaria_automatizada_{timestamp}.png"
        create_monetary_policy_image(df_filtered_for_display, filename)

        print(f"\n✅ Proceso completado exitosamente")
        print(f"📊 Datos obtenidos: {len(df_filtered_for_display)} instrumentos")
        print(f"🖼️ Imagen generada: {filename}")
        print(f"🤖 Chile TPM: Automatizado desde BCCh")

        return df_filtered_for_display
    else:
        print("❌ No se pudieron obtener datos de política monetaria para mostrar")
        return None

# Ejecutar el código
if __name__ == "__main__":
    # Ejecutar con Chile automatizado
    monetary_data = main()
# Out:
# 🚀 Iniciando obtención de datos...
# 🤖 Chile TPM: Automatizado desde API BCCh
# 📝 México: 8.0% (manual)
# 📝 Colombia: 9.25% (manual)
# 🔄 Calculando cambios en puntos básicos...
# 🔄 Obteniendo datos históricos de TPM Chile por scraping...
# ✅ Tasas de Chile encontradas:
#    🇨🇱 Actual: 4.75%
#    📈 Anterior: 5.0%
# ✅ Cambio TPM Chile calculado por scraping: -25pb
# ✅ Tasas encontradas:
#    📊 Actual: 8.0%
#    📈 Anterior: 8.5%
# ✅ México: Datos obtenidos por scraping - Actual: 8.0%, Cambio: -50.0 pb
# ✅ Tasas de Colombia encontradas:
#    🇨🇴 Actual: 9.25%
#    📈 Anterior: 9.25%
# ✅ Colombia: Datos obtenidos por scraping - Actual: 9.25%, Cambio: 0.0 pb
#
# ...
#    POLÍTICA MONETARIA
# ...
# INSTRUMENTO          SPOT (%)     CAMBIO 30D (pb) ESTADO
# --------------------------------------------------------------------------------
# 🤖 Selic Brasil       15.00%       0pb             ➡️ ESTABLE
# 🤖 TPM Chile          4.75%        -25pb           📉 BAJÓ
# ...
